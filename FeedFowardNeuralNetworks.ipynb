# %% [markdown]
# # CSE 572: Lab 8
#
# In this lab, you will practice implementing feed-forward and convolutional neural networks.
#
# To execute and make changes to this notebook, click File > Save a copy to save your own version in your Google Drive or Github. Read the step-by-step instructions below carefully. To execute the code, click on each cell below and press the SHIFT-ENTER keys simultaneously or by clicking the Play button.
#
# When you finish executing all code/exercises, save your notebook then download a copy (.ipynb file). Submit the following **three** things:
# 1. a link to your Colab notebook,
# 2. the .ipynb file, and
# 3. a pdf of the executed notebook on Canvas.
#
# To generate a pdf of the notebook, click File > Print > Save as PDF.

# %%
# Import libraries
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# Set the random seed for reproducibility
seed = 0
tf.random.set_seed(seed)

# %% [markdown]
# ## Feed-forward neural networks
#
# Describe

# %% [markdown]
# ### Load the dataset
#
# For this example, we will use the [Cleveland Heart Disease dataset](https://archive.ics.uci.edu/ml/datasets/heart+Disease). Review the dataset documentation to learn more about the attributes and other aspects of the dataset. The dataset consists of a CSV file with 303 rows. Each row contains information about a patient. There are 14 attribute columns and one binary class column (`target`) that reports whether or not a patient had a heart disease. We will train a feed-forward neural network model to predict whether or not a given patient has a heart disease based on the attribute values.

# %%
# Load the dataset
data = pd.read_csv("http://storage.googleapis.com/download.tensorflow.org/data/heart.csv")

# %%
# Print sample rows
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %%
# Print the number of rows and columns
data.shape
# Out:
# (303, 14)

# %% [markdown]
# Split the dataset into three randomly-sampled subsets: training (60%), validation (20%), and test (20%).

# %%
# YOUR CODE HERE
import numpy as np
train, val, test = np.split(data.sample(frac=1, random_state=0), [int(.6*len(data)), int(.8*len(data))])

# %% [markdown]
# Print the number of samples in each of the three subsets and the number of instances from each class. For example, for the training set you might print "The training set has __ instances (__ heart disease, __ no disease)".

# %%
# YOUR CODE HERE
print ("The training set has " + str(train['target'].size) + " instances (" + str(train['target'].value_counts()[1]) + " heart disease, " + str(train['target'].value_counts()[0]) + " no disease)")
print ("The Validation set has " + str(val['target'].size) + " instances (" + str(val['target'].value_counts()[1]) + " heart disease, " + str(val['target'].value_counts()[0]) + " no disease)")
print ("The Test set has " + str(test['target'].size) + " instances (" + str(test['target'].value_counts()[1]) + " heart disease, " + str(test['target'].value_counts()[0]) + " no disease)")
# Out:
# The training set has 181 instances (48 heart disease, 133 no disease)
# The Validation set has 61 instances (18 heart disease, 43 no disease)
# The Test set has 61 instances (17 heart disease, 44 no disease)

# %% [markdown]
# ### Prepare the dataset
#
# Before we can feed this dataset to our model for training and evaluation, we need to perform a few steps to get it ready:
# 1. Convert the dataframes to Dataset objects
# 2. Normalize the numerical feature values
# 3. Binarize the Categorical features by converting to one-hot encodings

# %%
# Convert dataframes to Dataset objects
def dataframe_to_dataset(df):
    df = df.copy()
    # Remove the target column and store in a separate array
    labels = df.pop('target')
    ds = tf.data.Dataset.from_tensor_slices((dict(df), labels))
    ds = ds.shuffle(buffer_size=len(df), reshuffle_each_iteration=False)
    return ds

train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %% [markdown]
# The Dataset object yields a tuple containing the input feature vector and target (class value): `(input, target)`. `input` is a dictionary of features and `target` is the value 0 or 1. The code below prints an example instance drawn from the training Dataset object.

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("\nTarget:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=63>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=3>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=135>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=252>, 'fbs': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'restecg': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'thalach': <tf.Tensor: shape=(), dtype=int64, numpy=172>, 'exang': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'oldpeak': <tf.Tensor: shape=(), dtype=float64, numpy=0.0>, 'slope': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'ca': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'thal': <tf.Tensor: shape=(), dtype=string, numpy=b'normal'>}
#
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# We can use the batch() function in keras to create batches from the full dataset for passing to the model. For the training dataset, we'll define a hyperparameter `batch_size` that we will set. For the validation and test sets, we will make the batch size equivalent to the size of the subset so all samples in that subset are evaluated each time the dataset is evaluated by the model.

# %%
test.shape[0]
# Out:
# 61

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(val.shape[0])
test_ds = test_ds.batch(test.shape[0])

# %% [markdown]
# There are seven categorical features in the dataset: `sex`, `cp`, `fbs`, `restecg`, `exang`, `ca`, and `thal`. You can read more about what these features mean in the [dataset documentation](https://archive.ics.uci.edu/ml/datasets/heart+Disease). All of them except `thal` have integer data type while `thal` has String data type. Below we define a function to encode these feature values as one-hot encodings using the [IntegerLookup()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/IntegerLookup) and [StringLookup()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/StringLookup) layers. These layers create look-up tables for mapping a set of arbitrary integers or strings to a one-hot encoding. We use an `is_string` argument to indicate whether we should use the `StringLookup()` for `thal` or the `IntegerLookup()` for the remaining features.

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    from tensorflow.keras.layers import IntegerLookup
    from tensorflow.keras.layers import StringLookup
    
    # Create lookup layer to turn categorical features into 1-hot integer encodings
    if is_string:
        lookup = StringLookup(output_mode="binary")
    else:
        lookup = IntegerLookup(output_mode="binary")

    # Prepare a Dataset that only yields the feature of interest
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Find the set of possible values and assign them a fixed integer index
    lookup.adapt(feature_ds)

    # Turn the input into integer indices
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# The remaining features in the dataset (`age`, `trestbps`, `chol`, `thalach`, `oldpeak`, and `slope`) are all numerical measurements. You can read more about what these features mean in the [dataset documentation](https://archive.ics.uci.edu/ml/datasets/heart+Disease). We don't need to encode the numerical features, but we do want to scale them to the same range of values (e.g., using standardization or normalization). Below we define a function that uses the [Normalization()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Normalization) layer to standardize the data (subtract the mean and divide by the standard deviation for each feature).

# %%
def normalize(feature, name, dataset):
    from tensorflow.keras.layers import Normalization
    
    # Create a Normalization layer for our feature
    normalizer = Normalization()

    # Prepare a Dataset that only yields the feature of interest
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the statistics of the data
    normalizer.adapt(feature_ds)

    # Normalize the input feature
    norm_feature = normalizer(feature)
    return norm_feature

# %% [markdown]
# Now we can apply these functions to each of our features and return an encoded/preprocessed input layer. We first create tensor variables for each of the inputs, then apply the appropriate function, then concatenate all of these input layers for each feature together to form a single input feature layer.

# %%
all_inputs = [
    keras.Input(shape=(1,), name="sex", dtype="int64"),
    keras.Input(shape=(1,), name="cp", dtype="int64"),
    keras.Input(shape=(1,), name="fbs", dtype="int64"),
    keras.Input(shape=(1,), name="restecg", dtype="int64"),
    keras.Input(shape=(1,), name="exang", dtype="int64"),
    keras.Input(shape=(1,), name="ca", dtype="int64"),
    keras.Input(shape=(1,), name="thal", dtype="string"),
    keras.Input(shape=(1,), name="age"),
    keras.Input(shape=(1,), name="trestbps"),
    keras.Input(shape=(1,), name="chol"),
    keras.Input(shape=(1,), name="thalach"),
    keras.Input(shape=(1,), name="oldpeak"),
    keras.Input(shape=(1,), name="slope"),
]

# %%
feature_layer = layers.concatenate(
    [
        encode_categorical_feature(all_inputs[0], "sex", train_ds, False),
        encode_categorical_feature(all_inputs[1], "cp", train_ds, False),
        encode_categorical_feature(all_inputs[2], "fbs", train_ds, False),
        encode_categorical_feature(all_inputs[3], "restecg", train_ds, False),
        encode_categorical_feature(all_inputs[4], "exang", train_ds, False),
        encode_categorical_feature(all_inputs[5], "ca", train_ds, False),
        encode_categorical_feature(all_inputs[6], "thal", train_ds, True),
        normalize(all_inputs[7], "age", train_ds),
        normalize(all_inputs[8], "trestbps", train_ds),
        normalize(all_inputs[9], "chol", train_ds),
        normalize(all_inputs[10], "thalach", train_ds),
        normalize(all_inputs[11], "oldpeak", train_ds),
        normalize(all_inputs[12], "slope", train_ds)
    ]
)

# %% [markdown]
# ### Build the model
#
# Now that we've prepared our dataset, we can construct our neural network model. We construct the model by composing Layer objects starting with the input layer (which we've already defined as `feature_layer`) and ending with the output layer (which will be the final output of the model). In this example, we will only use [Dense()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) layers which are simple fully-connected feed-forward layers (i.e., each output from layer `i-1` is connected by a weight variable to every neuron in layer `i`). We will create a network with only one hidden layer (between the input and output layers).
#
# The Dense() layer object allows us to specify the activation function to use using the `activation` argument. In class, we talked about several activation functions including sigmoid, sign, and tanh. Another commonly used activation function is the rectified linear unit, or "ReLU" function. Another commonly used activation function is the rectified linear unit, or "ReLU" function, which has the equation $a(z)=max(0,z)$. We will use `relu` as our activation function in this example for all layers except the final layer, which will use a `sigmoid` activation.

# %%
# Create a variable for the number of units/neurons in the layer
h1_units = 32
# Create a Dense layer and append it to the input layer
h1_layer = layers.Dense(h1_units, activation='relu')(feature_layer)

# Create an output layer with one output representing the likelihood of 
# heart disease and append it to the hidden layer
output_layer = layers.Dense(1, activation="sigmoid")(h1_layer)

# Build the model specifying the input and output layer
model = keras.Model(inputs=all_inputs, outputs=output_layer)
model_1000 = keras.Model(inputs=all_inputs, outputs=output_layer)

# %% [markdown]
# We can plot our completed model to visualize the input, hidden, and output layers.

# %%
# `rankdir='LR'` is to make the graph horizontal
keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Next we compile the model by specifying the optimization technique and loss function to be used in model training. We can also specify the metric(s) that will be logged during training. We will use stochastic gradient descent (`sgd`) for the optimizer and binary cross entropy (log loss) as the loss function. We will log the accuracy metric during training. We can also specify the learning rate hyperparameter here.

# %%
lr = 0.01
model.compile(keras.optimizers.SGD(learning_rate=lr), "binary_crossentropy", metrics=["accuracy"])
model_1000.compile(keras.optimizers.SGD(learning_rate=lr), "binary_crossentropy", metrics=["accuracy"])

# %% [markdown]
# ### Train the model
#
# Now that we've constructed and compiled our model, we can train the model using our training dataset. This is done in keras using the `fit()` function, which also gives us an option to provide the validation dataset which will be used to evaluate validation accuracy after every epoch.

# %%
model_result = model.fit(train_ds, epochs=100, validation_data=val_ds)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 56ms/step - loss: 0.5750 - accuracy: 0.7624 - val_loss: 0.5773 - val_accuracy: 0.7705
# Epoch 2/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5595 - accuracy: 0.7680 - val_loss: 0.5649 - val_accuracy: 0.7705
# Epoch 3/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5455 - accuracy: 0.7845 - val_loss: 0.5536 - val_accuracy: 0.7705
# Epoch 4/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5329 - accuracy: 0.7845 - val_loss: 0.5432 - val_accuracy: 0.7705
# Epoch 5/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5214 - accuracy: 0.7845 - val_loss: 0.5336 - val_accuracy: 0.7705
# Epoch 6/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5109 - accuracy: 0.7845 - val_loss: 0.5246 - val_accuracy: 0.7705
# Epoch 7/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5012 - accuracy: 0.7845 - val_loss: 0.5162 - val_accuracy: 0.7705
# Epoch 8/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4923 - accuracy: 0.7845 - val_loss: 0.5083 - val_accuracy: 0.7869
# Epoch 9/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4840 - accuracy: 0.7845 - val_loss: 0.5010 - val_accuracy: 0.7705
# Epoch 10/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4763 - accuracy: 0.7956 - val_loss: 0.4942 - val_accuracy: 0.7705
# Epoch 11/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4691 - accuracy: 0.7956 - val_loss: 0.4878 - val_accuracy: 0.7705
# Epoch 12/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4625 - accuracy: 0.8011 - val_loss: 0.4817 - val_accuracy: 0.7541
# Epoch 13/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4562 - accuracy: 0.8011 - val_loss: 0.4760 - val_accuracy: 0.7705
# Epoch 14/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.8011 - val_loss: 0.4707 - val_accuracy: 0.7705
# Epoch 15/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4447 - accuracy: 0.8122 - val_loss: 0.4655 - val_accuracy: 0.7705
# Epoch 16/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4395 - accuracy: 0.8122 - val_loss: 0.4606 - val_accuracy: 0.7705
# Epoch 17/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4345 - accuracy: 0.8122 - val_loss: 0.4560 - val_accuracy: 0.7705
# Epoch 18/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4297 - accuracy: 0.8122 - val_loss: 0.4515 - val_accuracy: 0.8033
# Epoch 19/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4253 - accuracy: 0.8122 - val_loss: 0.4473 - val_accuracy: 0.8197
# Epoch 20/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4210 - accuracy: 0.8066 - val_loss: 0.4432 - val_accuracy: 0.8197
# Epoch 21/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4169 - accuracy: 0.8011 - val_loss: 0.4393 - val_accuracy: 0.8197
# Epoch 22/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4129 - accuracy: 0.8011 - val_loss: 0.4356 - val_accuracy: 0.8197
# Epoch 23/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4092 - accuracy: 0.8011 - val_loss: 0.4321 - val_accuracy: 0.8197
# Epoch 24/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4056 - accuracy: 0.8011 - val_loss: 0.4286 - val_accuracy: 0.8197
# Epoch 25/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4021 - accuracy: 0.8011 - val_loss: 0.4253 - val_accuracy: 0.8197
# Epoch 26/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3988 - accuracy: 0.8011 - val_loss: 0.4222 - val_accuracy: 0.8197
# Epoch 27/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3957 - accuracy: 0.8011 - val_loss: 0.4192 - val_accuracy: 0.8197
# Epoch 28/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3926 - accuracy: 0.8122 - val_loss: 0.4163 - val_accuracy: 0.8361
# Epoch 29/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3896 - accuracy: 0.8177 - val_loss: 0.4135 - val_accuracy: 0.8361
# Epoch 30/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3868 - accuracy: 0.8122 - val_loss: 0.4108 - val_accuracy: 0.8361
# Epoch 31/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3840 - accuracy: 0.8122 - val_loss: 0.4082 - val_accuracy: 0.8361
# Epoch 32/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3813 - accuracy: 0.8122 - val_loss: 0.4056 - val_accuracy: 0.8361
# Epoch 33/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3788 - accuracy: 0.8177 - val_loss: 0.4032 - val_accuracy: 0.8361
# Epoch 34/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3762 - accuracy: 0.8232 - val_loss: 0.4008 - val_accuracy: 0.8361
# Epoch 35/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3738 - accuracy: 0.8287 - val_loss: 0.3985 - val_accuracy: 0.8361
# Epoch 36/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3714 - accuracy: 0.8287 - val_loss: 0.3963 - val_accuracy: 0.8361
# Epoch 37/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3691 - accuracy: 0.8287 - val_loss: 0.3942 - val_accuracy: 0.8361
# Epoch 38/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3669 - accuracy: 0.8287 - val_loss: 0.3922 - val_accuracy: 0.8361
# Epoch 39/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3647 - accuracy: 0.8232 - val_loss: 0.3902 - val_accuracy: 0.8361
# Epoch 40/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3626 - accuracy: 0.8287 - val_loss: 0.3884 - val_accuracy: 0.8361
# Epoch 41/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3605 - accuracy: 0.8287 - val_loss: 0.3865 - val_accuracy: 0.8361
# Epoch 42/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3585 - accuracy: 0.8287 - val_loss: 0.3847 - val_accuracy: 0.8361
# Epoch 43/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3566 - accuracy: 0.8287 - val_loss: 0.3830 - val_accuracy: 0.8361
# Epoch 44/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3547 - accuracy: 0.8287 - val_loss: 0.3814 - val_accuracy: 0.8361
# Epoch 45/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3529 - accuracy: 0.8287 - val_loss: 0.3798 - val_accuracy: 0.8361
# Epoch 46/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3511 - accuracy: 0.8287 - val_loss: 0.3782 - val_accuracy: 0.8361
# Epoch 47/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3494 - accuracy: 0.8287 - val_loss: 0.3767 - val_accuracy: 0.8361
# Epoch 48/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3477 - accuracy: 0.8287 - val_loss: 0.3752 - val_accuracy: 0.8361
# Epoch 49/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3461 - accuracy: 0.8343 - val_loss: 0.3738 - val_accuracy: 0.8361
# Epoch 50/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3445 - accuracy: 0.8398 - val_loss: 0.3724 - val_accuracy: 0.8361
# Epoch 51/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3429 - accuracy: 0.8398 - val_loss: 0.3711 - val_accuracy: 0.8361
# Epoch 52/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3414 - accuracy: 0.8398 - val_loss: 0.3698 - val_accuracy: 0.8361
# Epoch 53/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3399 - accuracy: 0.8398 - val_loss: 0.3685 - val_accuracy: 0.8361
# Epoch 54/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3384 - accuracy: 0.8398 - val_loss: 0.3673 - val_accuracy: 0.8361
# Epoch 55/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3370 - accuracy: 0.8398 - val_loss: 0.3660 - val_accuracy: 0.8361
# Epoch 56/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3356 - accuracy: 0.8398 - val_loss: 0.3649 - val_accuracy: 0.8525
# Epoch 57/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3343 - accuracy: 0.8398 - val_loss: 0.3637 - val_accuracy: 0.8525
# Epoch 58/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3329 - accuracy: 0.8398 - val_loss: 0.3626 - val_accuracy: 0.8525
# Epoch 59/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3316 - accuracy: 0.8398 - val_loss: 0.3615 - val_accuracy: 0.8525
# Epoch 60/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3304 - accuracy: 0.8398 - val_loss: 0.3604 - val_accuracy: 0.8525
# Epoch 61/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3291 - accuracy: 0.8398 - val_loss: 0.3594 - val_accuracy: 0.8525
# Epoch 62/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3279 - accuracy: 0.8398 - val_loss: 0.3584 - val_accuracy: 0.8525
# Epoch 63/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3267 - accuracy: 0.8398 - val_loss: 0.3575 - val_accuracy: 0.8525
# Epoch 64/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3255 - accuracy: 0.8398 - val_loss: 0.3566 - val_accuracy: 0.8525
# Epoch 65/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3244 - accuracy: 0.8398 - val_loss: 0.3557 - val_accuracy: 0.8525
# Epoch 66/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3233 - accuracy: 0.8398 - val_loss: 0.3548 - val_accuracy: 0.8525
# Epoch 67/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3222 - accuracy: 0.8398 - val_loss: 0.3539 - val_accuracy: 0.8525
# Epoch 68/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3212 - accuracy: 0.8398 - val_loss: 0.3531 - val_accuracy: 0.8525
# Epoch 69/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3201 - accuracy: 0.8398 - val_loss: 0.3523 - val_accuracy: 0.8525
# Epoch 70/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3191 - accuracy: 0.8398 - val_loss: 0.3515 - val_accuracy: 0.8525
# Epoch 71/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3181 - accuracy: 0.8398 - val_loss: 0.3507 - val_accuracy: 0.8525
# Epoch 72/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3172 - accuracy: 0.8398 - val_loss: 0.3499 - val_accuracy: 0.8689
# Epoch 73/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3162 - accuracy: 0.8398 - val_loss: 0.3492 - val_accuracy: 0.8689
# Epoch 74/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3153 - accuracy: 0.8398 - val_loss: 0.3485 - val_accuracy: 0.8689
# Epoch 75/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3143 - accuracy: 0.8398 - val_loss: 0.3478 - val_accuracy: 0.8689
# Epoch 76/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3134 - accuracy: 0.8453 - val_loss: 0.3471 - val_accuracy: 0.8689
# Epoch 77/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3125 - accuracy: 0.8453 - val_loss: 0.3464 - val_accuracy: 0.8689
# Epoch 78/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3116 - accuracy: 0.8453 - val_loss: 0.3457 - val_accuracy: 0.8689
# Epoch 79/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3108 - accuracy: 0.8453 - val_loss: 0.3451 - val_accuracy: 0.8689
# Epoch 80/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3099 - accuracy: 0.8508 - val_loss: 0.3445 - val_accuracy: 0.8689
# Epoch 81/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3091 - accuracy: 0.8508 - val_loss: 0.3439 - val_accuracy: 0.8689
# Epoch 82/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3082 - accuracy: 0.8564 - val_loss: 0.3433 - val_accuracy: 0.8689
# Epoch 83/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3074 - accuracy: 0.8564 - val_loss: 0.3427 - val_accuracy: 0.8689
# Epoch 84/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3066 - accuracy: 0.8564 - val_loss: 0.3421 - val_accuracy: 0.8689
# Epoch 85/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3058 - accuracy: 0.8619 - val_loss: 0.3416 - val_accuracy: 0.8689
# Epoch 86/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3050 - accuracy: 0.8619 - val_loss: 0.3410 - val_accuracy: 0.8689
# Epoch 87/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3042 - accuracy: 0.8619 - val_loss: 0.3405 - val_accuracy: 0.8689
# Epoch 88/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3034 - accuracy: 0.8619 - val_loss: 0.3400 - val_accuracy: 0.8689
# Epoch 89/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3027 - accuracy: 0.8619 - val_loss: 0.3395 - val_accuracy: 0.8689
# Epoch 90/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3019 - accuracy: 0.8619 - val_loss: 0.3390 - val_accuracy: 0.8689
# Epoch 91/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3012 - accuracy: 0.8619 - val_loss: 0.3385 - val_accuracy: 0.8689
# Epoch 92/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3004 - accuracy: 0.8619 - val_loss: 0.3381 - val_accuracy: 0.8689
# Epoch 93/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2997 - accuracy: 0.8674 - val_loss: 0.3376 - val_accuracy: 0.8689
# Epoch 94/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2990 - accuracy: 0.8674 - val_loss: 0.3372 - val_accuracy: 0.8689
# Epoch 95/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2983 - accuracy: 0.8674 - val_loss: 0.3367 - val_accuracy: 0.8689
# Epoch 96/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2976 - accuracy: 0.8674 - val_loss: 0.3363 - val_accuracy: 0.8689
# Epoch 97/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2969 - accuracy: 0.8674 - val_loss: 0.3359 - val_accuracy: 0.8689
# Epoch 98/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2962 - accuracy: 0.8674 - val_loss: 0.3355 - val_accuracy: 0.8689
# Epoch 99/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2955 - accuracy: 0.8674 - val_loss: 0.3351 - val_accuracy: 0.8689
# Epoch 100/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2949 - accuracy: 0.8729 - val_loss: 0.3347 - val_accuracy: 0.8689

# %% [markdown]
# The `fit()` function returns a history attribute that gives the metrics recorded during training as a dictionary. We can print the dictionary keys to see which metrics were stored:

# %%
model_result.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# Create a figure with two subplots. The first subplot should plot the training and validation loss (`loss` and `val_loss`) and the second subplot should plot the training and validation accuracy (`accuracy` and `val_accuracy`). Make sure you include the axis labels and a legend in each plot.

# %%
import matplotlib.pyplot as plt
L = list(range(1, 101))
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))
ax1.plot(L, model_result.history['loss'], label='Loss')
ax1.plot(L, model_result.history['val_loss'], label='Val_Loss')
ax1.set_xlabel("Epochs")
ax1.set_ylabel("Loss")
ax1.legend()
ax2.plot(L, model_result.history['accuracy'], label='Accuracy')
ax2.plot(L, model_result.history['val_accuracy'], label='Val_Accuracy')
ax1.set_xlabel("Epochs")
ax1.set_ylabel("Accuracy")
ax2.legend()
# YOUR CODE HERE

# %%
model_result_1000 = model_1000.fit(train_ds, epochs=1000, validation_data=val_ds)
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 1s 53ms/step - loss: 0.2942 - accuracy: 0.8729 - val_loss: 0.3343 - val_accuracy: 0.8689
# Epoch 2/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2936 - accuracy: 0.8729 - val_loss: 0.3339 - val_accuracy: 0.8689
# Epoch 3/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2929 - accuracy: 0.8729 - val_loss: 0.3336 - val_accuracy: 0.8689
# Epoch 4/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2923 - accuracy: 0.8729 - val_loss: 0.3332 - val_accuracy: 0.8689
# Epoch 5/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2917 - accuracy: 0.8729 - val_loss: 0.3329 - val_accuracy: 0.8689
# Epoch 6/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2910 - accuracy: 0.8729 - val_loss: 0.3325 - val_accuracy: 0.8689
# Epoch 7/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2904 - accuracy: 0.8785 - val_loss: 0.3322 - val_accuracy: 0.8689
# Epoch 8/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2898 - accuracy: 0.8785 - val_loss: 0.3318 - val_accuracy: 0.8689
# Epoch 9/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2892 - accuracy: 0.8785 - val_loss: 0.3315 - val_accuracy: 0.8689
# Epoch 10/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2886 - accuracy: 0.8785 - val_loss: 0.3312 - val_accuracy: 0.8689
# Epoch 11/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2881 - accuracy: 0.8785 - val_loss: 0.3309 - val_accuracy: 0.8689
# Epoch 12/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2875 - accuracy: 0.8785 - val_loss: 0.3306 - val_accuracy: 0.8689
# Epoch 13/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2869 - accuracy: 0.8785 - val_loss: 0.3303 - val_accuracy: 0.8689
# Epoch 14/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2863 - accuracy: 0.8785 - val_loss: 0.3300 - val_accuracy: 0.8689
# Epoch 15/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2858 - accuracy: 0.8785 - val_loss: 0.3297 - val_accuracy: 0.8689
# Epoch 16/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2852 - accuracy: 0.8785 - val_loss: 0.3294 - val_accuracy: 0.8689
# Epoch 17/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2846 - accuracy: 0.8785 - val_loss: 0.3292 - val_accuracy: 0.8689
# Epoch 18/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2841 - accuracy: 0.8785 - val_loss: 0.3289 - val_accuracy: 0.8689
# Epoch 19/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2835 - accuracy: 0.8785 - val_loss: 0.3286 - val_accuracy: 0.8689
# Epoch 20/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2830 - accuracy: 0.8785 - val_loss: 0.3283 - val_accuracy: 0.8689
# Epoch 21/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2824 - accuracy: 0.8785 - val_loss: 0.3281 - val_accuracy: 0.8689
# Epoch 22/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2819 - accuracy: 0.8785 - val_loss: 0.3278 - val_accuracy: 0.8689
# Epoch 23/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2814 - accuracy: 0.8785 - val_loss: 0.3276 - val_accuracy: 0.8689
# Epoch 24/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2808 - accuracy: 0.8785 - val_loss: 0.3273 - val_accuracy: 0.8689
# Epoch 25/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2803 - accuracy: 0.8785 - val_loss: 0.3271 - val_accuracy: 0.8689
# Epoch 26/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2798 - accuracy: 0.8785 - val_loss: 0.3268 - val_accuracy: 0.8689
# Epoch 27/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2793 - accuracy: 0.8785 - val_loss: 0.3266 - val_accuracy: 0.8689
# Epoch 28/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2787 - accuracy: 0.8785 - val_loss: 0.3263 - val_accuracy: 0.8689
# Epoch 29/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2782 - accuracy: 0.8785 - val_loss: 0.3261 - val_accuracy: 0.8689
# Epoch 30/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2777 - accuracy: 0.8785 - val_loss: 0.3259 - val_accuracy: 0.8689
# Epoch 31/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2772 - accuracy: 0.8785 - val_loss: 0.3257 - val_accuracy: 0.8689
# Epoch 32/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2767 - accuracy: 0.8785 - val_loss: 0.3254 - val_accuracy: 0.8689
# Epoch 33/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2762 - accuracy: 0.8785 - val_loss: 0.3252 - val_accuracy: 0.8689
# Epoch 34/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2757 - accuracy: 0.8785 - val_loss: 0.3250 - val_accuracy: 0.8689
# Epoch 35/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2752 - accuracy: 0.8785 - val_loss: 0.3247 - val_accuracy: 0.8689
# Epoch 36/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2748 - accuracy: 0.8785 - val_loss: 0.3245 - val_accuracy: 0.8689
# Epoch 37/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2743 - accuracy: 0.8840 - val_loss: 0.3243 - val_accuracy: 0.8689
# Epoch 38/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2738 - accuracy: 0.8840 - val_loss: 0.3240 - val_accuracy: 0.8689
# Epoch 39/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2733 - accuracy: 0.8840 - val_loss: 0.3238 - val_accuracy: 0.8689
# Epoch 40/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2729 - accuracy: 0.8840 - val_loss: 0.3236 - val_accuracy: 0.8689
# Epoch 41/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2724 - accuracy: 0.8840 - val_loss: 0.3234 - val_accuracy: 0.8689
# Epoch 42/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2719 - accuracy: 0.8895 - val_loss: 0.3231 - val_accuracy: 0.8689
# Epoch 43/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2715 - accuracy: 0.8895 - val_loss: 0.3229 - val_accuracy: 0.8689
# Epoch 44/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2710 - accuracy: 0.8895 - val_loss: 0.3227 - val_accuracy: 0.8689
# Epoch 45/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2706 - accuracy: 0.8950 - val_loss: 0.3225 - val_accuracy: 0.8689
# Epoch 46/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2701 - accuracy: 0.8950 - val_loss: 0.3222 - val_accuracy: 0.8689
# Epoch 47/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2697 - accuracy: 0.8950 - val_loss: 0.3220 - val_accuracy: 0.8689
# Epoch 48/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2692 - accuracy: 0.8950 - val_loss: 0.3218 - val_accuracy: 0.8689
# Epoch 49/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2688 - accuracy: 0.8950 - val_loss: 0.3216 - val_accuracy: 0.8689
# Epoch 50/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2684 - accuracy: 0.8950 - val_loss: 0.3213 - val_accuracy: 0.8689
# Epoch 51/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2679 - accuracy: 0.8950 - val_loss: 0.3211 - val_accuracy: 0.8689
# Epoch 52/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2675 - accuracy: 0.8950 - val_loss: 0.3209 - val_accuracy: 0.8689
# Epoch 53/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2671 - accuracy: 0.8950 - val_loss: 0.3207 - val_accuracy: 0.8689
# Epoch 54/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2667 - accuracy: 0.8950 - val_loss: 0.3205 - val_accuracy: 0.8689
# Epoch 55/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2663 - accuracy: 0.8950 - val_loss: 0.3203 - val_accuracy: 0.8689
# Epoch 56/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2658 - accuracy: 0.8950 - val_loss: 0.3201 - val_accuracy: 0.8689
# Epoch 57/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2654 - accuracy: 0.8950 - val_loss: 0.3199 - val_accuracy: 0.8689
# Epoch 58/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2650 - accuracy: 0.8950 - val_loss: 0.3197 - val_accuracy: 0.8689
# Epoch 59/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2646 - accuracy: 0.8950 - val_loss: 0.3195 - val_accuracy: 0.8689
# Epoch 60/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2642 - accuracy: 0.8950 - val_loss: 0.3193 - val_accuracy: 0.8689
# Epoch 61/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2639 - accuracy: 0.8950 - val_loss: 0.3191 - val_accuracy: 0.8689
# Epoch 62/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2635 - accuracy: 0.9006 - val_loss: 0.3189 - val_accuracy: 0.8689
# Epoch 63/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2631 - accuracy: 0.9006 - val_loss: 0.3187 - val_accuracy: 0.8689
# Epoch 64/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2628 - accuracy: 0.9006 - val_loss: 0.3185 - val_accuracy: 0.8689
# Epoch 65/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2624 - accuracy: 0.9006 - val_loss: 0.3183 - val_accuracy: 0.8689
# Epoch 66/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2620 - accuracy: 0.9006 - val_loss: 0.3181 - val_accuracy: 0.8689
# Epoch 67/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2617 - accuracy: 0.9061 - val_loss: 0.3179 - val_accuracy: 0.8689
# Epoch 68/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2613 - accuracy: 0.9061 - val_loss: 0.3178 - val_accuracy: 0.8689
# Epoch 69/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2610 - accuracy: 0.9061 - val_loss: 0.3176 - val_accuracy: 0.8689
# Epoch 70/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2606 - accuracy: 0.9061 - val_loss: 0.3174 - val_accuracy: 0.8689
# Epoch 71/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2602 - accuracy: 0.9061 - val_loss: 0.3172 - val_accuracy: 0.8689
# Epoch 72/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2599 - accuracy: 0.9061 - val_loss: 0.3171 - val_accuracy: 0.8689
# Epoch 73/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2596 - accuracy: 0.9061 - val_loss: 0.3169 - val_accuracy: 0.8689
# Epoch 74/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2592 - accuracy: 0.9061 - val_loss: 0.3167 - val_accuracy: 0.8689
# Epoch 75/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2589 - accuracy: 0.9061 - val_loss: 0.3166 - val_accuracy: 0.8689
# Epoch 76/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2585 - accuracy: 0.9061 - val_loss: 0.3164 - val_accuracy: 0.8689
# Epoch 77/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2582 - accuracy: 0.9061 - val_loss: 0.3162 - val_accuracy: 0.8689
# Epoch 78/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2579 - accuracy: 0.9061 - val_loss: 0.3161 - val_accuracy: 0.8689
# Epoch 79/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2575 - accuracy: 0.9061 - val_loss: 0.3159 - val_accuracy: 0.8689
# Epoch 80/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2572 - accuracy: 0.9061 - val_loss: 0.3157 - val_accuracy: 0.8689
# Epoch 81/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2569 - accuracy: 0.9061 - val_loss: 0.3156 - val_accuracy: 0.8689
# Epoch 82/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2565 - accuracy: 0.9061 - val_loss: 0.3154 - val_accuracy: 0.8689
# Epoch 83/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2562 - accuracy: 0.9061 - val_loss: 0.3153 - val_accuracy: 0.8689
# Epoch 84/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2559 - accuracy: 0.9061 - val_loss: 0.3151 - val_accuracy: 0.8689
# Epoch 85/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2556 - accuracy: 0.9061 - val_loss: 0.3150 - val_accuracy: 0.8689
# Epoch 86/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2553 - accuracy: 0.9061 - val_loss: 0.3148 - val_accuracy: 0.8689
# Epoch 87/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2550 - accuracy: 0.9061 - val_loss: 0.3147 - val_accuracy: 0.8689
# Epoch 88/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2546 - accuracy: 0.9061 - val_loss: 0.3145 - val_accuracy: 0.8852
# Epoch 89/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2543 - accuracy: 0.9061 - val_loss: 0.3144 - val_accuracy: 0.8852
# Epoch 90/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2540 - accuracy: 0.9061 - val_loss: 0.3142 - val_accuracy: 0.8852
# Epoch 91/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2537 - accuracy: 0.9061 - val_loss: 0.3141 - val_accuracy: 0.8852
# Epoch 92/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2534 - accuracy: 0.9061 - val_loss: 0.3139 - val_accuracy: 0.8852
# Epoch 93/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2531 - accuracy: 0.9116 - val_loss: 0.3138 - val_accuracy: 0.8852
# Epoch 94/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2528 - accuracy: 0.9116 - val_loss: 0.3137 - val_accuracy: 0.8852
# Epoch 95/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2525 - accuracy: 0.9116 - val_loss: 0.3135 - val_accuracy: 0.8852
# Epoch 96/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2522 - accuracy: 0.9116 - val_loss: 0.3134 - val_accuracy: 0.8852
# Epoch 97/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2519 - accuracy: 0.9116 - val_loss: 0.3132 - val_accuracy: 0.8852
# Epoch 98/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2516 - accuracy: 0.9116 - val_loss: 0.3131 - val_accuracy: 0.8852
# Epoch 99/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2513 - accuracy: 0.9116 - val_loss: 0.3129 - val_accuracy: 0.8852
# Epoch 100/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2510 - accuracy: 0.9116 - val_loss: 0.3128 - val_accuracy: 0.8852
# Epoch 101/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2507 - accuracy: 0.9116 - val_loss: 0.3127 - val_accuracy: 0.8852
# Epoch 102/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2504 - accuracy: 0.9116 - val_loss: 0.3125 - val_accuracy: 0.8852
# Epoch 103/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2501 - accuracy: 0.9116 - val_loss: 0.3124 - val_accuracy: 0.8852
# Epoch 104/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2498 - accuracy: 0.9061 - val_loss: 0.3123 - val_accuracy: 0.8852
# Epoch 105/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2496 - accuracy: 0.9061 - val_loss: 0.3122 - val_accuracy: 0.8852
# Epoch 106/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2493 - accuracy: 0.9061 - val_loss: 0.3120 - val_accuracy: 0.8852
# Epoch 107/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2490 - accuracy: 0.9061 - val_loss: 0.3119 - val_accuracy: 0.8852
# Epoch 108/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2487 - accuracy: 0.9061 - val_loss: 0.3118 - val_accuracy: 0.8852
# Epoch 109/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2484 - accuracy: 0.9061 - val_loss: 0.3117 - val_accuracy: 0.8852
# Epoch 110/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2481 - accuracy: 0.9061 - val_loss: 0.3115 - val_accuracy: 0.8852
# Epoch 111/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2479 - accuracy: 0.9061 - val_loss: 0.3114 - val_accuracy: 0.8852
# Epoch 112/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2476 - accuracy: 0.9061 - val_loss: 0.3113 - val_accuracy: 0.8852
# Epoch 113/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2473 - accuracy: 0.9061 - val_loss: 0.3112 - val_accuracy: 0.8852
# Epoch 114/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2470 - accuracy: 0.9061 - val_loss: 0.3111 - val_accuracy: 0.8852
# Epoch 115/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2468 - accuracy: 0.9061 - val_loss: 0.3110 - val_accuracy: 0.8852
# Epoch 116/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2465 - accuracy: 0.9061 - val_loss: 0.3109 - val_accuracy: 0.8852
# Epoch 117/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2462 - accuracy: 0.9116 - val_loss: 0.3108 - val_accuracy: 0.8852
# Epoch 118/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2460 - accuracy: 0.9116 - val_loss: 0.3107 - val_accuracy: 0.8852
# Epoch 119/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2457 - accuracy: 0.9116 - val_loss: 0.3106 - val_accuracy: 0.8852
# Epoch 120/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2454 - accuracy: 0.9116 - val_loss: 0.3105 - val_accuracy: 0.8852
# Epoch 121/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2451 - accuracy: 0.9116 - val_loss: 0.3104 - val_accuracy: 0.8852
# Epoch 122/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2449 - accuracy: 0.9116 - val_loss: 0.3104 - val_accuracy: 0.8852
# Epoch 123/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2446 - accuracy: 0.9116 - val_loss: 0.3103 - val_accuracy: 0.8852
# Epoch 124/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2444 - accuracy: 0.9116 - val_loss: 0.3102 - val_accuracy: 0.8852
# Epoch 125/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2441 - accuracy: 0.9116 - val_loss: 0.3101 - val_accuracy: 0.8852
# Epoch 126/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2438 - accuracy: 0.9116 - val_loss: 0.3100 - val_accuracy: 0.8852
# Epoch 127/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2436 - accuracy: 0.9116 - val_loss: 0.3099 - val_accuracy: 0.8852
# Epoch 128/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2433 - accuracy: 0.9116 - val_loss: 0.3098 - val_accuracy: 0.8852
# Epoch 129/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2431 - accuracy: 0.9116 - val_loss: 0.3098 - val_accuracy: 0.8852
# Epoch 130/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2428 - accuracy: 0.9116 - val_loss: 0.3097 - val_accuracy: 0.8852
# Epoch 131/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2425 - accuracy: 0.9116 - val_loss: 0.3096 - val_accuracy: 0.8852
# Epoch 132/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2423 - accuracy: 0.9116 - val_loss: 0.3095 - val_accuracy: 0.9016
# Epoch 133/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2420 - accuracy: 0.9116 - val_loss: 0.3095 - val_accuracy: 0.9016
# Epoch 134/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2418 - accuracy: 0.9116 - val_loss: 0.3094 - val_accuracy: 0.9016
# Epoch 135/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2415 - accuracy: 0.9116 - val_loss: 0.3093 - val_accuracy: 0.9016
# Epoch 136/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2413 - accuracy: 0.9116 - val_loss: 0.3092 - val_accuracy: 0.9016
# Epoch 137/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2410 - accuracy: 0.9116 - val_loss: 0.3092 - val_accuracy: 0.9016
# Epoch 138/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2408 - accuracy: 0.9116 - val_loss: 0.3091 - val_accuracy: 0.9016
# Epoch 139/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2405 - accuracy: 0.9116 - val_loss: 0.3090 - val_accuracy: 0.9016
# Epoch 140/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2403 - accuracy: 0.9116 - val_loss: 0.3089 - val_accuracy: 0.9016
# Epoch 141/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2400 - accuracy: 0.9116 - val_loss: 0.3089 - val_accuracy: 0.9016
# Epoch 142/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2398 - accuracy: 0.9116 - val_loss: 0.3088 - val_accuracy: 0.9016
# Epoch 143/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2395 - accuracy: 0.9116 - val_loss: 0.3087 - val_accuracy: 0.9016
# Epoch 144/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2393 - accuracy: 0.9116 - val_loss: 0.3087 - val_accuracy: 0.9016
# Epoch 145/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2390 - accuracy: 0.9116 - val_loss: 0.3086 - val_accuracy: 0.9016
# Epoch 146/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2388 - accuracy: 0.9116 - val_loss: 0.3086 - val_accuracy: 0.9016
# Epoch 147/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2386 - accuracy: 0.9116 - val_loss: 0.3085 - val_accuracy: 0.9016
# Epoch 148/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2383 - accuracy: 0.9116 - val_loss: 0.3084 - val_accuracy: 0.9016
# Epoch 149/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2381 - accuracy: 0.9116 - val_loss: 0.3084 - val_accuracy: 0.9016
# Epoch 150/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2378 - accuracy: 0.9116 - val_loss: 0.3083 - val_accuracy: 0.9016
# Epoch 151/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2376 - accuracy: 0.9116 - val_loss: 0.3083 - val_accuracy: 0.9016
# Epoch 152/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2373 - accuracy: 0.9116 - val_loss: 0.3082 - val_accuracy: 0.9016
# Epoch 153/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2371 - accuracy: 0.9116 - val_loss: 0.3082 - val_accuracy: 0.9016
# Epoch 154/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2369 - accuracy: 0.9116 - val_loss: 0.3081 - val_accuracy: 0.9016
# Epoch 155/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2366 - accuracy: 0.9116 - val_loss: 0.3081 - val_accuracy: 0.9016
# Epoch 156/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2364 - accuracy: 0.9116 - val_loss: 0.3080 - val_accuracy: 0.9016
# Epoch 157/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2361 - accuracy: 0.9116 - val_loss: 0.3080 - val_accuracy: 0.9016
# Epoch 158/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2359 - accuracy: 0.9116 - val_loss: 0.3079 - val_accuracy: 0.9016
# Epoch 159/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2357 - accuracy: 0.9116 - val_loss: 0.3079 - val_accuracy: 0.9016
# Epoch 160/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2354 - accuracy: 0.9116 - val_loss: 0.3078 - val_accuracy: 0.9016
# Epoch 161/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2352 - accuracy: 0.9116 - val_loss: 0.3078 - val_accuracy: 0.9016
# Epoch 162/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2350 - accuracy: 0.9116 - val_loss: 0.3078 - val_accuracy: 0.9016
# Epoch 163/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2347 - accuracy: 0.9116 - val_loss: 0.3077 - val_accuracy: 0.9016
# Epoch 164/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2345 - accuracy: 0.9116 - val_loss: 0.3077 - val_accuracy: 0.9016
# Epoch 165/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2343 - accuracy: 0.9116 - val_loss: 0.3077 - val_accuracy: 0.9016
# Epoch 166/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2340 - accuracy: 0.9116 - val_loss: 0.3076 - val_accuracy: 0.9016
# Epoch 167/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2338 - accuracy: 0.9116 - val_loss: 0.3076 - val_accuracy: 0.9016
# Epoch 168/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2336 - accuracy: 0.9116 - val_loss: 0.3075 - val_accuracy: 0.9016
# Epoch 169/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2333 - accuracy: 0.9116 - val_loss: 0.3075 - val_accuracy: 0.9016
# Epoch 170/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2331 - accuracy: 0.9116 - val_loss: 0.3075 - val_accuracy: 0.9016
# Epoch 171/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2329 - accuracy: 0.9116 - val_loss: 0.3074 - val_accuracy: 0.9016
# Epoch 172/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2327 - accuracy: 0.9116 - val_loss: 0.3073 - val_accuracy: 0.9016
# Epoch 173/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2324 - accuracy: 0.9116 - val_loss: 0.3073 - val_accuracy: 0.9016
# Epoch 174/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2322 - accuracy: 0.9116 - val_loss: 0.3073 - val_accuracy: 0.9016
# Epoch 175/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2320 - accuracy: 0.9116 - val_loss: 0.3072 - val_accuracy: 0.9016
# Epoch 176/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2318 - accuracy: 0.9116 - val_loss: 0.3072 - val_accuracy: 0.9016
# Epoch 177/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2316 - accuracy: 0.9116 - val_loss: 0.3071 - val_accuracy: 0.9016
# Epoch 178/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2313 - accuracy: 0.9116 - val_loss: 0.3071 - val_accuracy: 0.9016
# Epoch 179/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2311 - accuracy: 0.9116 - val_loss: 0.3071 - val_accuracy: 0.9016
# Epoch 180/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2309 - accuracy: 0.9116 - val_loss: 0.3070 - val_accuracy: 0.9016
# Epoch 181/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2307 - accuracy: 0.9116 - val_loss: 0.3070 - val_accuracy: 0.9016
# Epoch 182/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2305 - accuracy: 0.9116 - val_loss: 0.3070 - val_accuracy: 0.9016
# Epoch 183/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2303 - accuracy: 0.9116 - val_loss: 0.3069 - val_accuracy: 0.9016
# Epoch 184/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2301 - accuracy: 0.9116 - val_loss: 0.3069 - val_accuracy: 0.9016
# Epoch 185/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2299 - accuracy: 0.9116 - val_loss: 0.3069 - val_accuracy: 0.9016
# Epoch 186/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2297 - accuracy: 0.9116 - val_loss: 0.3068 - val_accuracy: 0.9016
# Epoch 187/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2294 - accuracy: 0.9116 - val_loss: 0.3068 - val_accuracy: 0.9016
# Epoch 188/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2292 - accuracy: 0.9116 - val_loss: 0.3068 - val_accuracy: 0.9016
# Epoch 189/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2290 - accuracy: 0.9116 - val_loss: 0.3068 - val_accuracy: 0.9016
# Epoch 190/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2288 - accuracy: 0.9171 - val_loss: 0.3067 - val_accuracy: 0.9016
# Epoch 191/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2286 - accuracy: 0.9171 - val_loss: 0.3067 - val_accuracy: 0.9016
# Epoch 192/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2284 - accuracy: 0.9171 - val_loss: 0.3067 - val_accuracy: 0.9016
# Epoch 193/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2282 - accuracy: 0.9171 - val_loss: 0.3067 - val_accuracy: 0.9016
# Epoch 194/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2280 - accuracy: 0.9171 - val_loss: 0.3067 - val_accuracy: 0.9016
# Epoch 195/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2278 - accuracy: 0.9171 - val_loss: 0.3067 - val_accuracy: 0.9016
# Epoch 196/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2276 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.9016
# Epoch 197/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2274 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.9016
# Epoch 198/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2272 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.9016
# Epoch 199/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2270 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.9016
# Epoch 200/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2268 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.9016
# Epoch 201/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2266 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.9016
# Epoch 202/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2264 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.9016
# Epoch 203/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2262 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.9016
# Epoch 204/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2260 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.9016
# Epoch 205/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2258 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.9016
# Epoch 206/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2256 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.9016
# Epoch 207/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2254 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.9016
# Epoch 208/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2252 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.9016
# Epoch 209/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2250 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.9016
# Epoch 210/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2248 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.9016
# Epoch 211/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2246 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 212/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2244 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 213/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2242 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 214/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2240 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 215/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2238 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 216/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2236 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 217/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2235 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 218/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2233 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 219/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2231 - accuracy: 0.9171 - val_loss: 0.3064 - val_accuracy: 0.8852
# Epoch 220/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2229 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 221/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2227 - accuracy: 0.9171 - val_loss: 0.3064 - val_accuracy: 0.8852
# Epoch 222/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2225 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 223/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2223 - accuracy: 0.9171 - val_loss: 0.3064 - val_accuracy: 0.8852
# Epoch 224/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2221 - accuracy: 0.9171 - val_loss: 0.3064 - val_accuracy: 0.8852
# Epoch 225/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2219 - accuracy: 0.9171 - val_loss: 0.3064 - val_accuracy: 0.8852
# Epoch 226/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2217 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 227/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2215 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 228/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2213 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 229/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2211 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 230/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2209 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 231/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2207 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 232/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2205 - accuracy: 0.9171 - val_loss: 0.3065 - val_accuracy: 0.8852
# Epoch 233/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2203 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.8852
# Epoch 234/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2201 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.8852
# Epoch 235/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2199 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.8689
# Epoch 236/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2197 - accuracy: 0.9171 - val_loss: 0.3066 - val_accuracy: 0.8689
# Epoch 237/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2195 - accuracy: 0.9171 - val_loss: 0.3067 - val_accuracy: 0.8689
# Epoch 238/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2193 - accuracy: 0.9171 - val_loss: 0.3067 - val_accuracy: 0.8689
# Epoch 239/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2191 - accuracy: 0.9171 - val_loss: 0.3067 - val_accuracy: 0.8689
# Epoch 240/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2189 - accuracy: 0.9171 - val_loss: 0.3067 - val_accuracy: 0.8689
# Epoch 241/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2187 - accuracy: 0.9171 - val_loss: 0.3068 - val_accuracy: 0.8689
# Epoch 242/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2185 - accuracy: 0.9171 - val_loss: 0.3068 - val_accuracy: 0.8689
# Epoch 243/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2183 - accuracy: 0.9171 - val_loss: 0.3068 - val_accuracy: 0.8689
# Epoch 244/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2181 - accuracy: 0.9171 - val_loss: 0.3068 - val_accuracy: 0.8689
# Epoch 245/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2179 - accuracy: 0.9171 - val_loss: 0.3068 - val_accuracy: 0.8689
# Epoch 246/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2177 - accuracy: 0.9171 - val_loss: 0.3069 - val_accuracy: 0.8689
# Epoch 247/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2175 - accuracy: 0.9171 - val_loss: 0.3069 - val_accuracy: 0.8689
# Epoch 248/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2173 - accuracy: 0.9171 - val_loss: 0.3069 - val_accuracy: 0.8689
# Epoch 249/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2171 - accuracy: 0.9171 - val_loss: 0.3069 - val_accuracy: 0.8689
# Epoch 250/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2169 - accuracy: 0.9171 - val_loss: 0.3069 - val_accuracy: 0.8689
# Epoch 251/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2167 - accuracy: 0.9171 - val_loss: 0.3070 - val_accuracy: 0.8689
# Epoch 252/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2165 - accuracy: 0.9171 - val_loss: 0.3070 - val_accuracy: 0.8689
# Epoch 253/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2163 - accuracy: 0.9171 - val_loss: 0.3070 - val_accuracy: 0.8689
# Epoch 254/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2161 - accuracy: 0.9171 - val_loss: 0.3071 - val_accuracy: 0.8689
# Epoch 255/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2159 - accuracy: 0.9171 - val_loss: 0.3071 - val_accuracy: 0.8689
# Epoch 256/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2157 - accuracy: 0.9171 - val_loss: 0.3071 - val_accuracy: 0.8689
# Epoch 257/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2155 - accuracy: 0.9171 - val_loss: 0.3071 - val_accuracy: 0.8689
# Epoch 258/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2153 - accuracy: 0.9171 - val_loss: 0.3071 - val_accuracy: 0.8689
# Epoch 259/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2151 - accuracy: 0.9227 - val_loss: 0.3072 - val_accuracy: 0.8689
# Epoch 260/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2149 - accuracy: 0.9227 - val_loss: 0.3072 - val_accuracy: 0.8689
# Epoch 261/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2147 - accuracy: 0.9227 - val_loss: 0.3072 - val_accuracy: 0.8689
# Epoch 262/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2145 - accuracy: 0.9227 - val_loss: 0.3072 - val_accuracy: 0.8689
# Epoch 263/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2143 - accuracy: 0.9227 - val_loss: 0.3073 - val_accuracy: 0.8689
# Epoch 264/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2141 - accuracy: 0.9227 - val_loss: 0.3073 - val_accuracy: 0.8689
# Epoch 265/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2140 - accuracy: 0.9227 - val_loss: 0.3073 - val_accuracy: 0.8689
# Epoch 266/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2137 - accuracy: 0.9227 - val_loss: 0.3074 - val_accuracy: 0.8689
# Epoch 267/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2136 - accuracy: 0.9227 - val_loss: 0.3074 - val_accuracy: 0.8689
# Epoch 268/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2134 - accuracy: 0.9227 - val_loss: 0.3074 - val_accuracy: 0.8689
# Epoch 269/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2132 - accuracy: 0.9227 - val_loss: 0.3075 - val_accuracy: 0.8689
# Epoch 270/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2130 - accuracy: 0.9227 - val_loss: 0.3075 - val_accuracy: 0.8689
# Epoch 271/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2128 - accuracy: 0.9227 - val_loss: 0.3075 - val_accuracy: 0.8689
# Epoch 272/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2126 - accuracy: 0.9227 - val_loss: 0.3075 - val_accuracy: 0.8689
# Epoch 273/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2124 - accuracy: 0.9227 - val_loss: 0.3075 - val_accuracy: 0.8689
# Epoch 274/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2122 - accuracy: 0.9227 - val_loss: 0.3076 - val_accuracy: 0.8689
# Epoch 275/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2120 - accuracy: 0.9227 - val_loss: 0.3076 - val_accuracy: 0.8689
# Epoch 276/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2118 - accuracy: 0.9227 - val_loss: 0.3076 - val_accuracy: 0.8689
# Epoch 277/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2117 - accuracy: 0.9227 - val_loss: 0.3076 - val_accuracy: 0.8689
# Epoch 278/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2115 - accuracy: 0.9227 - val_loss: 0.3076 - val_accuracy: 0.8689
# Epoch 279/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2113 - accuracy: 0.9227 - val_loss: 0.3077 - val_accuracy: 0.8689
# Epoch 280/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2111 - accuracy: 0.9227 - val_loss: 0.3077 - val_accuracy: 0.8689
# Epoch 281/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2109 - accuracy: 0.9227 - val_loss: 0.3077 - val_accuracy: 0.8689
# Epoch 282/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2107 - accuracy: 0.9227 - val_loss: 0.3077 - val_accuracy: 0.8689
# Epoch 283/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2105 - accuracy: 0.9227 - val_loss: 0.3077 - val_accuracy: 0.8689
# Epoch 284/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2103 - accuracy: 0.9227 - val_loss: 0.3078 - val_accuracy: 0.8689
# Epoch 285/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2102 - accuracy: 0.9227 - val_loss: 0.3078 - val_accuracy: 0.8689
# Epoch 286/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2100 - accuracy: 0.9227 - val_loss: 0.3078 - val_accuracy: 0.8689
# Epoch 287/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2098 - accuracy: 0.9227 - val_loss: 0.3078 - val_accuracy: 0.8689
# Epoch 288/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2096 - accuracy: 0.9227 - val_loss: 0.3079 - val_accuracy: 0.8689
# Epoch 289/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2094 - accuracy: 0.9227 - val_loss: 0.3079 - val_accuracy: 0.8689
# Epoch 290/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2092 - accuracy: 0.9227 - val_loss: 0.3079 - val_accuracy: 0.8689
# Epoch 291/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2090 - accuracy: 0.9227 - val_loss: 0.3079 - val_accuracy: 0.8689
# Epoch 292/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2089 - accuracy: 0.9227 - val_loss: 0.3079 - val_accuracy: 0.8689
# Epoch 293/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2087 - accuracy: 0.9227 - val_loss: 0.3080 - val_accuracy: 0.8689
# Epoch 294/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2085 - accuracy: 0.9227 - val_loss: 0.3080 - val_accuracy: 0.8689
# Epoch 295/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2083 - accuracy: 0.9227 - val_loss: 0.3080 - val_accuracy: 0.8689
# Epoch 296/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2081 - accuracy: 0.9227 - val_loss: 0.3080 - val_accuracy: 0.8689
# Epoch 297/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2079 - accuracy: 0.9227 - val_loss: 0.3081 - val_accuracy: 0.8689
# Epoch 298/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2078 - accuracy: 0.9227 - val_loss: 0.3081 - val_accuracy: 0.8689
# Epoch 299/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2076 - accuracy: 0.9227 - val_loss: 0.3081 - val_accuracy: 0.8689
# Epoch 300/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2074 - accuracy: 0.9227 - val_loss: 0.3081 - val_accuracy: 0.8689
# Epoch 301/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2072 - accuracy: 0.9227 - val_loss: 0.3082 - val_accuracy: 0.8689
# Epoch 302/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2071 - accuracy: 0.9227 - val_loss: 0.3082 - val_accuracy: 0.8689
# Epoch 303/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2069 - accuracy: 0.9227 - val_loss: 0.3082 - val_accuracy: 0.8689
# Epoch 304/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2067 - accuracy: 0.9227 - val_loss: 0.3083 - val_accuracy: 0.8689
# Epoch 305/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2065 - accuracy: 0.9227 - val_loss: 0.3083 - val_accuracy: 0.8689
# Epoch 306/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2063 - accuracy: 0.9227 - val_loss: 0.3083 - val_accuracy: 0.8689
# Epoch 307/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2062 - accuracy: 0.9227 - val_loss: 0.3083 - val_accuracy: 0.8689
# Epoch 308/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2060 - accuracy: 0.9227 - val_loss: 0.3084 - val_accuracy: 0.8689
# Epoch 309/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2058 - accuracy: 0.9227 - val_loss: 0.3084 - val_accuracy: 0.8689
# Epoch 310/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2056 - accuracy: 0.9227 - val_loss: 0.3085 - val_accuracy: 0.8689
# Epoch 311/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2055 - accuracy: 0.9227 - val_loss: 0.3085 - val_accuracy: 0.8689
# Epoch 312/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2053 - accuracy: 0.9227 - val_loss: 0.3085 - val_accuracy: 0.8689
# Epoch 313/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2051 - accuracy: 0.9227 - val_loss: 0.3085 - val_accuracy: 0.8689
# Epoch 314/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2049 - accuracy: 0.9337 - val_loss: 0.3086 - val_accuracy: 0.8689
# Epoch 315/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2048 - accuracy: 0.9337 - val_loss: 0.3086 - val_accuracy: 0.8689
# Epoch 316/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2046 - accuracy: 0.9337 - val_loss: 0.3086 - val_accuracy: 0.8689
# Epoch 317/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2044 - accuracy: 0.9337 - val_loss: 0.3086 - val_accuracy: 0.8689
# Epoch 318/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2043 - accuracy: 0.9337 - val_loss: 0.3087 - val_accuracy: 0.8689
# Epoch 319/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2041 - accuracy: 0.9337 - val_loss: 0.3087 - val_accuracy: 0.8689
# Epoch 320/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2039 - accuracy: 0.9337 - val_loss: 0.3087 - val_accuracy: 0.8689
# Epoch 321/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2037 - accuracy: 0.9337 - val_loss: 0.3087 - val_accuracy: 0.8689
# Epoch 322/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2036 - accuracy: 0.9337 - val_loss: 0.3087 - val_accuracy: 0.8689
# Epoch 323/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2034 - accuracy: 0.9337 - val_loss: 0.3087 - val_accuracy: 0.8689
# Epoch 324/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2032 - accuracy: 0.9337 - val_loss: 0.3088 - val_accuracy: 0.8689
# Epoch 325/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2031 - accuracy: 0.9337 - val_loss: 0.3088 - val_accuracy: 0.8689
# Epoch 326/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2029 - accuracy: 0.9337 - val_loss: 0.3088 - val_accuracy: 0.8689
# Epoch 327/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2027 - accuracy: 0.9337 - val_loss: 0.3088 - val_accuracy: 0.8689
# Epoch 328/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2026 - accuracy: 0.9337 - val_loss: 0.3089 - val_accuracy: 0.8689
# Epoch 329/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2024 - accuracy: 0.9337 - val_loss: 0.3089 - val_accuracy: 0.8689
# Epoch 330/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2022 - accuracy: 0.9337 - val_loss: 0.3089 - val_accuracy: 0.8689
# Epoch 331/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2021 - accuracy: 0.9337 - val_loss: 0.3089 - val_accuracy: 0.8689
# Epoch 332/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2019 - accuracy: 0.9337 - val_loss: 0.3090 - val_accuracy: 0.8689
# Epoch 333/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2017 - accuracy: 0.9337 - val_loss: 0.3090 - val_accuracy: 0.8689
# Epoch 334/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2016 - accuracy: 0.9337 - val_loss: 0.3090 - val_accuracy: 0.8689
# Epoch 335/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2014 - accuracy: 0.9337 - val_loss: 0.3090 - val_accuracy: 0.8689
# Epoch 336/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2012 - accuracy: 0.9337 - val_loss: 0.3091 - val_accuracy: 0.8689
# Epoch 337/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2011 - accuracy: 0.9337 - val_loss: 0.3091 - val_accuracy: 0.8689
# Epoch 338/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2009 - accuracy: 0.9337 - val_loss: 0.3091 - val_accuracy: 0.8689
# Epoch 339/1000
# ...
# Epoch 889/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1307 - accuracy: 0.9669 - val_loss: 0.3429 - val_accuracy: 0.8689
# Epoch 890/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1306 - accuracy: 0.9669 - val_loss: 0.3430 - val_accuracy: 0.8689
# Epoch 891/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1305 - accuracy: 0.9669 - val_loss: 0.3432 - val_accuracy: 0.8689
# Epoch 892/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1304 - accuracy: 0.9669 - val_loss: 0.3432 - val_accuracy: 0.8689
# Epoch 893/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1303 - accuracy: 0.9669 - val_loss: 0.3434 - val_accuracy: 0.8689
# Epoch 894/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1302 - accuracy: 0.9669 - val_loss: 0.3435 - val_accuracy: 0.8689
# Epoch 895/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1301 - accuracy: 0.9669 - val_loss: 0.3436 - val_accuracy: 0.8689
# Epoch 896/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1299 - accuracy: 0.9669 - val_loss: 0.3437 - val_accuracy: 0.8689
# Epoch 897/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1298 - accuracy: 0.9669 - val_loss: 0.3438 - val_accuracy: 0.8689
# Epoch 898/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1297 - accuracy: 0.9669 - val_loss: 0.3439 - val_accuracy: 0.8689
# Epoch 899/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1296 - accuracy: 0.9669 - val_loss: 0.3440 - val_accuracy: 0.8689
# Epoch 900/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1295 - accuracy: 0.9669 - val_loss: 0.3441 - val_accuracy: 0.8689
# Epoch 901/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1294 - accuracy: 0.9669 - val_loss: 0.3443 - val_accuracy: 0.8689
# Epoch 902/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1293 - accuracy: 0.9669 - val_loss: 0.3444 - val_accuracy: 0.8689
# Epoch 903/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1292 - accuracy: 0.9669 - val_loss: 0.3445 - val_accuracy: 0.8689
# Epoch 904/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1291 - accuracy: 0.9669 - val_loss: 0.3446 - val_accuracy: 0.8689
# Epoch 905/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1290 - accuracy: 0.9669 - val_loss: 0.3447 - val_accuracy: 0.8689
# Epoch 906/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1289 - accuracy: 0.9669 - val_loss: 0.3448 - val_accuracy: 0.8689
# Epoch 907/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1288 - accuracy: 0.9669 - val_loss: 0.3449 - val_accuracy: 0.8689
# Epoch 908/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1287 - accuracy: 0.9669 - val_loss: 0.3450 - val_accuracy: 0.8689
# Epoch 909/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1286 - accuracy: 0.9669 - val_loss: 0.3451 - val_accuracy: 0.8689
# Epoch 910/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1285 - accuracy: 0.9669 - val_loss: 0.3453 - val_accuracy: 0.8689
# Epoch 911/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1283 - accuracy: 0.9669 - val_loss: 0.3454 - val_accuracy: 0.8689
# Epoch 912/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1283 - accuracy: 0.9669 - val_loss: 0.3454 - val_accuracy: 0.8689
# Epoch 913/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1282 - accuracy: 0.9669 - val_loss: 0.3456 - val_accuracy: 0.8689
# Epoch 914/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1280 - accuracy: 0.9669 - val_loss: 0.3457 - val_accuracy: 0.8689
# Epoch 915/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1279 - accuracy: 0.9669 - val_loss: 0.3458 - val_accuracy: 0.8689
# Epoch 916/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1278 - accuracy: 0.9669 - val_loss: 0.3459 - val_accuracy: 0.8689
# Epoch 917/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1277 - accuracy: 0.9669 - val_loss: 0.3460 - val_accuracy: 0.8689
# Epoch 918/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1276 - accuracy: 0.9669 - val_loss: 0.3462 - val_accuracy: 0.8689
# Epoch 919/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1275 - accuracy: 0.9669 - val_loss: 0.3463 - val_accuracy: 0.8689
# Epoch 920/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1274 - accuracy: 0.9669 - val_loss: 0.3464 - val_accuracy: 0.8689
# Epoch 921/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1273 - accuracy: 0.9669 - val_loss: 0.3464 - val_accuracy: 0.8689
# Epoch 922/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1272 - accuracy: 0.9669 - val_loss: 0.3466 - val_accuracy: 0.8689
# Epoch 923/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1271 - accuracy: 0.9669 - val_loss: 0.3467 - val_accuracy: 0.8689
# Epoch 924/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1270 - accuracy: 0.9669 - val_loss: 0.3468 - val_accuracy: 0.8689
# Epoch 925/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1269 - accuracy: 0.9669 - val_loss: 0.3469 - val_accuracy: 0.8689
# Epoch 926/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1268 - accuracy: 0.9669 - val_loss: 0.3470 - val_accuracy: 0.8689
# Epoch 927/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1267 - accuracy: 0.9669 - val_loss: 0.3471 - val_accuracy: 0.8689
# Epoch 928/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1266 - accuracy: 0.9669 - val_loss: 0.3473 - val_accuracy: 0.8689
# Epoch 929/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1265 - accuracy: 0.9669 - val_loss: 0.3473 - val_accuracy: 0.8689
# Epoch 930/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1264 - accuracy: 0.9669 - val_loss: 0.3475 - val_accuracy: 0.8689
# Epoch 931/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1263 - accuracy: 0.9669 - val_loss: 0.3476 - val_accuracy: 0.8689
# Epoch 932/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1262 - accuracy: 0.9669 - val_loss: 0.3477 - val_accuracy: 0.8689
# Epoch 933/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1260 - accuracy: 0.9669 - val_loss: 0.3479 - val_accuracy: 0.8689
# Epoch 934/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1259 - accuracy: 0.9669 - val_loss: 0.3480 - val_accuracy: 0.8689
# Epoch 935/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1258 - accuracy: 0.9669 - val_loss: 0.3481 - val_accuracy: 0.8689
# Epoch 936/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1257 - accuracy: 0.9669 - val_loss: 0.3482 - val_accuracy: 0.8689
# Epoch 937/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1256 - accuracy: 0.9669 - val_loss: 0.3483 - val_accuracy: 0.8689
# Epoch 938/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1255 - accuracy: 0.9669 - val_loss: 0.3484 - val_accuracy: 0.8689
# Epoch 939/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1254 - accuracy: 0.9669 - val_loss: 0.3486 - val_accuracy: 0.8689
# Epoch 940/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1253 - accuracy: 0.9669 - val_loss: 0.3487 - val_accuracy: 0.8689
# Epoch 941/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1252 - accuracy: 0.9669 - val_loss: 0.3488 - val_accuracy: 0.8689
# Epoch 942/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1251 - accuracy: 0.9669 - val_loss: 0.3489 - val_accuracy: 0.8689
# Epoch 943/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1250 - accuracy: 0.9669 - val_loss: 0.3491 - val_accuracy: 0.8689
# Epoch 944/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1249 - accuracy: 0.9669 - val_loss: 0.3491 - val_accuracy: 0.8689
# Epoch 945/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1248 - accuracy: 0.9669 - val_loss: 0.3493 - val_accuracy: 0.8689
# Epoch 946/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1247 - accuracy: 0.9669 - val_loss: 0.3494 - val_accuracy: 0.8689
# Epoch 947/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1246 - accuracy: 0.9669 - val_loss: 0.3495 - val_accuracy: 0.8689
# Epoch 948/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1245 - accuracy: 0.9669 - val_loss: 0.3496 - val_accuracy: 0.8689
# Epoch 949/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1244 - accuracy: 0.9669 - val_loss: 0.3497 - val_accuracy: 0.8689
# Epoch 950/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1243 - accuracy: 0.9724 - val_loss: 0.3498 - val_accuracy: 0.8689
# Epoch 951/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1242 - accuracy: 0.9724 - val_loss: 0.3499 - val_accuracy: 0.8689
# Epoch 952/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1240 - accuracy: 0.9724 - val_loss: 0.3501 - val_accuracy: 0.8689
# Epoch 953/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1240 - accuracy: 0.9724 - val_loss: 0.3501 - val_accuracy: 0.8689
# Epoch 954/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1239 - accuracy: 0.9724 - val_loss: 0.3503 - val_accuracy: 0.8689
# Epoch 955/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1237 - accuracy: 0.9724 - val_loss: 0.3503 - val_accuracy: 0.8689
# Epoch 956/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1236 - accuracy: 0.9724 - val_loss: 0.3505 - val_accuracy: 0.8689
# Epoch 957/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1235 - accuracy: 0.9724 - val_loss: 0.3506 - val_accuracy: 0.8689
# Epoch 958/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1234 - accuracy: 0.9779 - val_loss: 0.3507 - val_accuracy: 0.8689
# Epoch 959/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1233 - accuracy: 0.9779 - val_loss: 0.3508 - val_accuracy: 0.8689
# Epoch 960/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1232 - accuracy: 0.9779 - val_loss: 0.3509 - val_accuracy: 0.8689
# Epoch 961/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1231 - accuracy: 0.9779 - val_loss: 0.3510 - val_accuracy: 0.8689
# Epoch 962/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1230 - accuracy: 0.9779 - val_loss: 0.3512 - val_accuracy: 0.8689
# Epoch 963/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1229 - accuracy: 0.9779 - val_loss: 0.3513 - val_accuracy: 0.8689
# Epoch 964/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1228 - accuracy: 0.9779 - val_loss: 0.3513 - val_accuracy: 0.8689
# Epoch 965/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1227 - accuracy: 0.9779 - val_loss: 0.3514 - val_accuracy: 0.8689
# Epoch 966/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1226 - accuracy: 0.9779 - val_loss: 0.3516 - val_accuracy: 0.8689
# Epoch 967/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1225 - accuracy: 0.9779 - val_loss: 0.3517 - val_accuracy: 0.8689
# Epoch 968/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1224 - accuracy: 0.9779 - val_loss: 0.3519 - val_accuracy: 0.8689
# Epoch 969/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1223 - accuracy: 0.9779 - val_loss: 0.3519 - val_accuracy: 0.8689
# Epoch 970/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1222 - accuracy: 0.9779 - val_loss: 0.3520 - val_accuracy: 0.8689
# Epoch 971/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1221 - accuracy: 0.9779 - val_loss: 0.3522 - val_accuracy: 0.8689
# Epoch 972/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1220 - accuracy: 0.9779 - val_loss: 0.3523 - val_accuracy: 0.8689
# Epoch 973/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1219 - accuracy: 0.9779 - val_loss: 0.3524 - val_accuracy: 0.8689
# Epoch 974/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1218 - accuracy: 0.9779 - val_loss: 0.3524 - val_accuracy: 0.8689
# Epoch 975/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1217 - accuracy: 0.9779 - val_loss: 0.3526 - val_accuracy: 0.8689
# Epoch 976/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1216 - accuracy: 0.9779 - val_loss: 0.3527 - val_accuracy: 0.8689
# Epoch 977/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1215 - accuracy: 0.9779 - val_loss: 0.3528 - val_accuracy: 0.8689
# Epoch 978/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1214 - accuracy: 0.9779 - val_loss: 0.3530 - val_accuracy: 0.8689
# Epoch 979/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1213 - accuracy: 0.9779 - val_loss: 0.3531 - val_accuracy: 0.8689
# Epoch 980/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1212 - accuracy: 0.9779 - val_loss: 0.3532 - val_accuracy: 0.8689
# Epoch 981/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1211 - accuracy: 0.9779 - val_loss: 0.3533 - val_accuracy: 0.8689
# Epoch 982/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1210 - accuracy: 0.9779 - val_loss: 0.3534 - val_accuracy: 0.8689
# Epoch 983/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1209 - accuracy: 0.9779 - val_loss: 0.3535 - val_accuracy: 0.8689
# Epoch 984/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1208 - accuracy: 0.9779 - val_loss: 0.3536 - val_accuracy: 0.8689
# Epoch 985/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1207 - accuracy: 0.9779 - val_loss: 0.3537 - val_accuracy: 0.8689
# Epoch 986/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1206 - accuracy: 0.9779 - val_loss: 0.3539 - val_accuracy: 0.8689
# Epoch 987/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1205 - accuracy: 0.9779 - val_loss: 0.3540 - val_accuracy: 0.8689
# Epoch 988/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1204 - accuracy: 0.9779 - val_loss: 0.3541 - val_accuracy: 0.8689
# Epoch 989/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1203 - accuracy: 0.9779 - val_loss: 0.3541 - val_accuracy: 0.8689
# Epoch 990/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1202 - accuracy: 0.9779 - val_loss: 0.3543 - val_accuracy: 0.8689
# Epoch 991/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1201 - accuracy: 0.9779 - val_loss: 0.3544 - val_accuracy: 0.8689
# Epoch 992/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1200 - accuracy: 0.9779 - val_loss: 0.3545 - val_accuracy: 0.8689
# Epoch 993/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1199 - accuracy: 0.9779 - val_loss: 0.3546 - val_accuracy: 0.8689
# Epoch 994/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1198 - accuracy: 0.9779 - val_loss: 0.3548 - val_accuracy: 0.8689
# Epoch 995/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1197 - accuracy: 0.9779 - val_loss: 0.3549 - val_accuracy: 0.8689
# Epoch 996/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1196 - accuracy: 0.9779 - val_loss: 0.3550 - val_accuracy: 0.8689
# Epoch 997/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1195 - accuracy: 0.9779 - val_loss: 0.3551 - val_accuracy: 0.8689
# Epoch 998/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1194 - accuracy: 0.9779 - val_loss: 0.3552 - val_accuracy: 0.8689
# Epoch 999/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1193 - accuracy: 0.9779 - val_loss: 0.3553 - val_accuracy: 0.8689
# Epoch 1000/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1192 - accuracy: 0.9779 - val_loss: 0.3555 - val_accuracy: 0.8689

# %%
import matplotlib.pyplot as plt
L = list(range(1, 1001))
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))
ax1.plot(L, model_result_1000.history['loss'])
ax1.plot(L, model_result_1000.history['val_loss'])
ax2.plot(L, model_result_1000.history['accuracy'])
ax2.plot(L, model_result_1000.history['val_accuracy'])
# YOUR CODE HERE

# %% [markdown]
# **Question 1: If we train our model for too long (too many epochs), we run the risk of overfitting to the training data which will have a negative effect on our model's generalization to the validation dataset. Try changing the number of epochs to 1000 and re-training. Around how many epochs do you see the model begin to overfit?**
#
# **Answer:**
#
# YOUR ANSWER HERE
# The model starts overfitting when training accuracy increases and the validation accuracy starts decreasing. It can be observed from accuracy to val accuracy plot for 1000 epocs. Val accuracy drops after around 200 epochs. Model overfits from 200 epochs.

# %% [markdown]
# ### Test the model
#
# Finally, we evaluate our trained model on the held-out test set. First we predict the outputs for the test data.

# %%
preds = model.predict(test_ds)

# %% [markdown]
# The model output from the final sigmoid layer is a value between 0 and 1 representing the likelihood that a given sample patient has heart disease. To get the predicted classes, we predict 1 if the output was >= 0.5 and 0 otherwise.

# %%
pred_classes = [1 if p >= 0.5 else 0 for p in preds]

# %% [markdown]
# Compute and print the test accuracy.

# %%
#test['target']
test_t = [y.numpy() for x,y in test_ds][0]

# %%
from sklearn.metrics import accuracy_score
print('Accuracy on test data %.5f' % (accuracy_score(test_t, pred_classes)))
# YOUR CODE HERE
# Out:
# Accuracy on test data 0.78689

# %% [markdown]
# **Question 2: There is a large difference between the training and validation accuracies and the test accuracy. What do you think could explain this difference?**
#
# **Answer:**
#
# YOUR ANSWER HERE
# It is because the split could be in such a way that train data and val data have similar kind of entries. So, the val accuracy is more and test data contains new patterns which are not part of train data.
#
# When I have retrained the model with split using random state 42 the accuracy increased to 0.7 as the shuffling is the issue.

# %% [markdown]
# ## Convolutional neural networks
#
# The previous example used a structured dataset of pre-determined features to predict the likelihood of heart disease in a patient. This type of dataset is well suited for a feed-forward neural network (FFNN) architecture. However, other datasets may not be as well suited for this type of architecture. For example, to train a FFNN to classify an image dataset, we would need to convert each image (which has dimension $N \times M \times K$ where $N$ and $M$ are the image dimensions and $K$ is the number of color channels - 3 for RGB) to a feature vector representation. We can do this by flattening the image to a 1D feature vector so the new dimension would be $N * M * K \times 1$, but this would remove the 2D spatial structure.
#
# Convolutional neural networks (CNNs) are another type of neural network architecture that enables spatial relationships to be learned from the data. The features learned in each hidden layer have 2D structures that act as filters on the spatial inputs, rather than scalar activations like in a FFNN. In this example, we'll train a CNN to classify an image dataset.

# %% [markdown]
# ### Load the dataset
#
# For this example we'll use the [FashionMNIST dataset](https://keras.io/api/datasets/fashion_mnist/). This is a dataset of 60,000 28x28 color training images and 10,000 test images with 10 class labels:
#
# 0.	t-shirt
# 1.	trouser
# 2.	pullover
# 3.	dress
# 4.	coat
# 5.	sandal
# 6.	shirt
# 7.	sneaker
# 8.	bag
# 9.	boot

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
# Print the dimensions of the datasets

print('Training data input dim: ', x_train.shape)
print('Training data label dim: ', y_train.shape)
print('Test data input dim: ', x_test.shape)
print('Test data label dim: ', y_test.shape)
# Out:
# Training data input dim:  (60000, 28, 28)
# Training data label dim:  (60000,)
# Test data input dim:  (10000, 28, 28)
# Test data label dim:  (10000,)

# %%
# Set variable for number of classes
num_classes = 10

# %% [markdown]
# Next we'll plot a few random images from the training set to get an idea of what the data look like. You can run this as many times as you want to see a different random subset of images.

# %%
# number of images to plot
n = 5

# create a dictionary for the label names
labels = {
    0: 't-shirt',
    1: 'trouser',
    2: 'pullover',
    3: 'dress',
    4: 'coat',
    5: 'sandal',
    6: 'shirt',
    7: 'sneaker',
    8: 'bag',
    9: 'boot'
}


# Randomly sample n sample indices
rand_inds = np.random.randint(0, x_train.shape[0], n)

fig, axes = plt.subplots(ncols=n)
for i, ax in enumerate(axes):
    ax.imshow(x_train[rand_inds[i]], cmap='gray')
    ax.set_title(labels[y_train[rand_inds[i]]])
    ax.axis('off')

# %% [markdown]
# The class is currently a categorical variable with values 0 to 9. We need to convert this to a one-hot integer encoding.

# %%
# convert class category to one hot vector
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ### Build the model
#
# We will construct a model in the same way as the previous example by composing layers starting with the input layer and ending with the output layer. However in this example, we will use [Conv2D()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) layers instead of Dense() layers as our hidden layers. In addition to specifying the number of neurons/filters and activation function for each Conv2D() layer, we need to specify the kernel size (the size of the convolutional kernel/filter). We will use $3\times3$ convolutions for all layers in this example. Each Conv2D() layer is followed by a [MaxPool2D()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D) layer to enable invariance to small translations.
#
# We will still use a Dense() layer for the final output layer. Previously we used the sigmoid activation in our final layer, but this is only used for binary classification outputs (0 to 1). Since this is a multi-class classification, we will use the [softmax function](https://www.tensorflow.org/api_docs/python/tf/keras/activations/softmax) which returns the log odds for the multi-class case.

# %%
# Define the input layer
input_layer = keras.Input(shape=[x_train.shape[1], x_train.shape[2], 1])

# Define one hidden layer of Conv2D + Max Pooling
h1 = layers.Conv2D(32, kernel_size=(3, 3), activation="relu")(input_layer)
h1 = layers.MaxPooling2D(pool_size=(2, 2))(h1)

# Define a second Conv2D layer with 64 units, 3x3 kernel, and relu activation
h2 = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(h1)# YOUR CODE HERE

# Define a second MaxPooling2D layer with 2x2 pool size
h2 = layers.MaxPooling2D(pool_size=(2, 2))(h2)# YOUR CODE HERE

# Flatten the output from the last hidden layer so it can be passed to Dense layer
h2 = layers.Flatten()(h2)

# Final output layer
output = layers.Dense(num_classes, activation="softmax")(h2)

# Build the model specifying the input and output layer
model = keras.Model(inputs=input_layer, outputs=output)

# %% [markdown]
# We can plot our completed model to visualize the input, hidden, and output layers.

# %%
# `rankdir='LR'` is to make the graph horizontal
keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Another way to visualize our model is to print a table of the layers and the shape of the representation at each layer using the `model.summary()` function.

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense_2 (Dense)             (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model
#
# Now that we've constructed our model, we can compile and train the model as in the previous example. Since we are doing a multi-class classification, we use the [categorical cross-entropy](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/categorical_crossentropy) loss function instead of binary-cross entropy.
#
# In the first example, we created our own train/val/test subsets. In this example, the FashionMNIST dataset provided a train/test split but not a validation subset. We can have keras automatically split out a fraction of the training data using the `validation_split` argument to `model.fit()` as shown below.

# %%
batch_size = 512
epochs = 10

model.compile(loss="categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])

model_result = model.fit(x_train, y_train, 
                         batch_size=batch_size,
                         epochs=epochs, 
                         validation_split=0.2)
# Out:
# Epoch 1/10
# 94/94 [==============================] - 27s 279ms/step - loss: 13.9555 - accuracy: 0.2237 - val_loss: 1.9591 - val_accuracy: 0.3773
# Epoch 2/10
# 94/94 [==============================] - 32s 342ms/step - loss: 1.5469 - accuracy: 0.5068 - val_loss: 1.1200 - val_accuracy: 0.5926
# Epoch 3/10
# 94/94 [==============================] - 25s 269ms/step - loss: 0.9673 - accuracy: 0.6524 - val_loss: 0.8872 - val_accuracy: 0.6873
# Epoch 4/10
# 94/94 [==============================] - 25s 269ms/step - loss: 0.8173 - accuracy: 0.7097 - val_loss: 0.8796 - val_accuracy: 0.6812
# Epoch 5/10
# 94/94 [==============================] - 25s 270ms/step - loss: 0.7361 - accuracy: 0.7386 - val_loss: 0.7467 - val_accuracy: 0.7310
# Epoch 6/10
# 94/94 [==============================] - 26s 278ms/step - loss: 0.6870 - accuracy: 0.7554 - val_loss: 0.6725 - val_accuracy: 0.7639
# Epoch 7/10
# 94/94 [==============================] - 25s 268ms/step - loss: 0.6514 - accuracy: 0.7682 - val_loss: 0.6887 - val_accuracy: 0.7572
# Epoch 8/10
# 94/94 [==============================] - 26s 278ms/step - loss: 0.6241 - accuracy: 0.7791 - val_loss: 0.6229 - val_accuracy: 0.7787
# Epoch 9/10
# 94/94 [==============================] - 25s 270ms/step - loss: 0.6007 - accuracy: 0.7861 - val_loss: 0.6480 - val_accuracy: 0.7690
# Epoch 10/10
# 94/94 [==============================] - 25s 270ms/step - loss: 0.5792 - accuracy: 0.7944 - val_loss: 0.5892 - val_accuracy: 0.7922

# %% [markdown]
# Create a figure with two subplots. The first subplot should plot the training and validation loss (`loss` and `val_loss`) and the second subplot should plot the training and validation accuracy (`accuracy` and `val_accuracy`). Make sure you include the axis labels and a legend in each plot.

# %%
model_result.history['val_loss']
# Out:
# [1.9590787887573242,
#  1.119998812675476,
#  0.8872014880180359,
#  0.8795965313911438,
#  0.7466841340065002,
#  0.6724991202354431,
#  0.688704252243042,
#  0.6229314208030701,
#  0.6479644775390625,
#  0.5892376899719238]

# %%
import matplotlib.pyplot as plt
L = list(range(1, 11))
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))
ax1.plot(L, model_result.history['loss'], label='Loss')
ax1.plot(L, model_result.history['val_loss'], label='Val_Loss')
ax1.set_xlabel("Epochs")
ax1.set_ylabel("Loss")
ax1.legend()
ax2.plot(L, model_result.history['accuracy'], label='Accuracy')
ax2.plot(L , model_result.history['val_accuracy'], label='Val_Accuracy')
ax2.set_xlabel("Epochs")
ax2.set_ylabel("Accuracy")
ax2.legend()
# YOUR CODE HERE

# %% [markdown]
# Compute and print the test set accuracy. Note that your final accuracy may be different each time you run this due to the randomness in the validation split.

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

print("Test accuracy:", test_acc)
# Out:
# Test accuracy: 0.7915999889373779
